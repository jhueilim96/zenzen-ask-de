# %% [markdown]
# ### General API call flow
#
# #### Steps
#
# 1. Producer = Prepare API request
#    1. Get template from folder
#    2. Get ANIME seed from seed folder
#    3. One media per producer task
#       1. Producer loop through page
#       2. Wait result to arive
#       3. check `hasNextPage=True`
#       4. Repeat
#    4. Render variables
#       1. perPage = 25 (max allowed)
#       2. `current_page` parameteriz
#    5. Manager
#       1. Singleton implementation
#       2. class attribute `api_call_count` to keep track all running jobs & get updated by header `X-RATE-LIMIT-REMAINING-API`
#       3. Decide to start new producer task
#       4. Require timer of 60 seconds to know duration of waiting when limit is hit
# 2. Consumer = Response parser and storage
#    1. Parse `data` key
#    2. Set storage destinationjson -> 1 json per api call

# %%
from pathlib import Path
import aiohttp
from queue import Queue
import os
import asyncio
import json
import duckdb 
import time

# %%
async def make_api_call(url, query, variables):
    async with aiohttp.ClientSession() as session:
        async with session.post(url, json={'query': query, 'variables': variables}) as resp:
            result = await resp.json()
            header = resp.headers
            status_code = resp.status
            return result, resp
        
async def producer(queue, ids:list[int], url, query, max_per_page):
    print("Producer: Started")
    remaining_request = 90

    for id in ids:

        has_next_page = True
        current_page = 0

        while has_next_page:

            variables = {  
                'page': current_page,
                'perPage': max_per_page,
                'media_id': id
            }

            if remaining_request < 10:
                print("Pause to recover limit")
                await asyncio.sleep(30)

            print(f"Requesting page {current_page} for {id}")
            result, resp = await make_api_call(url, query, variables)            
            header = resp.headers

            if resp.status != 200:
                print(f"Request fails at {id}")
                raise resp.raise_for_status()

            await queue.put((result, id, current_page))
            remaining_request = int(header.get('x-ratelimit-remaining'))
            print(f'Remaining API call per min: {remaining_request}')

            has_next_page = result.get('data').get('Media').get('characters').get('pageInfo').get('hasNextPage')
            
            if has_next_page:
                current_page += 1
            else:
                print(f'{id} has completed all pagination')
                break

    print('Producer: Done')

# %%
async def save_api_to_local(file_path:str, data: dict):
    with open(file_path, 'w') as fp:
        json.dump(data, fp)

async def consumer(queue:asyncio.Queue, storage_path:Path):
    print("Consumer: Started")
    while True:

        response_body, id, current_page = await queue.get()
        filename = Path(f'{id}-{current_page}.json')
        file_path = storage_path / filename
        print(f'Saving {id} at {file_path.as_posix()}')
        await save_api_to_local(file_path=str(file_path), data=response_body)
        queue.task_done()
        print(f'Saving {id} completed')

# %%
# API Initialization
MAX_PER_PAGE = 25
MAX_API_PER_MIN = 90
SEED_BATCH_SIZE = 50

url = 'https://graphql.anilist.co'

# Storage 
base_path = Path().cwd().parent
storage_path = base_path / Path('raw/entity/anime-character')
seed_path = base_path / Path('raw/seed/top-anime.csv')

seeds = duckdb.read_csv(str(seed_path))
total_rows = seeds.shape[0]

template_path = Path(r'graphql-template\get-anime-character.graphql')
with open(str(template_path), 'r') as fp:
    template = fp.read()

# %%
for batches in range(500, seeds.shape[0], SEED_BATCH_SIZE):

    seeds_batch = duckdb.sql(f"""
        SELECT media_id 
        FROM seeds
        LIMIT {SEED_BATCH_SIZE}
        OFFSET {batches}
    """).fetchall()
    ids = [_[0] for _ in seeds_batch]

    print(f"Batch: {batches}")

    queue = asyncio.Queue(SEED_BATCH_SIZE)
    # start the consumer
    _ = asyncio.create_task(consumer(queue, storage_path))
    # start the producer and wait for it to finish
    await asyncio.create_task(producer(queue, ids, url, template, MAX_PER_PAGE))
    # wait for all items to be processed
    await queue.join()
# Out:
# Batch: 500
# Consumer: Started
# Producer: Started
# Requesting page 0 for 859
# Remaining API call per min: 89
# Requesting page 1 for 859
# Saving 859 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/859-0.json
# Saving 859 completed
# Remaining API call per min: 88
# Requesting page 2 for 859
# Saving 859 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/859-1.json
# Saving 859 completed
# Remaining API call per min: 87
# 859 has completed all pagination
# Requesting page 0 for 864
# Saving 859 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/859-2.json
# Saving 859 completed
# Remaining API call per min: 86
# 864 has completed all pagination
# Requesting page 0 for 870
# Saving 864 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/864-0.json
# Saving 864 completed
# Remaining API call per min: 85
# 870 has completed all pagination
# Requesting page 0 for 873
# Saving 870 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/870-0.json
# Saving 870 completed
# Remaining API call per min: 84
# Requesting page 1 for 873
# Saving 873 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/873-0.json
# Saving 873 completed
# Remaining API call per min: 83
# Requesting page 2 for 873
# Saving 873 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/873-1.json
# Saving 873 completed
# Remaining API call per min: 82
# 873 has completed all pagination
# Requesting page 0 for 881
# Saving 873 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/873-2.json
# Saving 873 completed
# Remaining API call per min: 81
# 881 has completed all pagination
# Requesting page 0 for 887
# Saving 881 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/881-0.json
# Saving 881 completed
# Remaining API call per min: 80
# 887 has completed all pagination
# Requesting page 0 for 25
# Saving 887 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/887-0.json
# Saving 887 completed
# Remaining API call per min: 79
# 25 has completed all pagination
# Requesting page 0 for 351
# Saving 25 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/25-0.json
# Saving 25 completed
# Remaining API call per min: 78
# Requesting page 1 for 351
# Saving 351 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/351-0.json
# Saving 351 completed
# Remaining API call per min: 77
# Requesting page 2 for 351
# Saving 351 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/351-1.json
# Saving 351 completed
# Remaining API call per min: 76
# 351 has completed all pagination
# Requesting page 0 for 358
# Saving 351 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/351-2.json
# Saving 351 completed
# Remaining API call per min: 75
# 358 has completed all pagination
# Requesting page 0 for 370
# Saving 358 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/358-0.json
# Saving 358 completed
# Remaining API call per min: 74
# Requesting page 1 for 370
# Saving 370 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/370-0.json
# Saving 370 completed
# Remaining API call per min: 73
# Requesting page 2 for 370
# Saving 370 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/370-1.json
# Saving 370 completed
# Remaining API call per min: 72
# 370 has completed all pagination
# Requesting page 0 for 374
# Saving 370 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/370-2.json
# Saving 370 completed
# Remaining API call per min: 71
# 374 has completed all pagination
# Requesting page 0 for 377
# Saving 374 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/374-0.json
# Saving 374 completed
# Remaining API call per min: 70
# 377 has completed all pagination
# Requesting page 0 for 394
# Saving 377 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/377-0.json
# Saving 377 completed
# Remaining API call per min: 69
# 394 has completed all pagination
# Requesting page 0 for 395
# Saving 394 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/394-0.json
# Saving 394 completed
# Remaining API call per min: 68
# 395 has completed all pagination
# Requesting page 0 for 415
# Saving 395 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/395-0.json
# Saving 395 completed
# Remaining API call per min: 67
# 415 has completed all pagination
# Requesting page 0 for 416
# Saving 415 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/415-0.json
# Saving 415 completed
# Remaining API call per min: 66
# 416 has completed all pagination
# Requesting page 0 for 419
# Saving 416 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/416-0.json
# Saving 416 completed
# Remaining API call per min: 65
# Requesting page 1 for 419
# Saving 419 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/419-0.json
# Saving 419 completed
# Remaining API call per min: 64
# Requesting page 2 for 419
# Saving 419 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/419-1.json
# Saving 419 completed
# Remaining API call per min: 63
# 419 has completed all pagination
# Requesting page 0 for 421
# Saving 419 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/419-2.json
# Saving 419 completed
# Remaining API call per min: 62
# 421 has completed all pagination
# Requesting page 0 for 424
# Saving 421 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/421-0.json
# Saving 421 completed
# Remaining API call per min: 61
# 424 has completed all pagination
# Requesting page 0 for 449
# Saving 424 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/424-0.json
# Saving 424 completed
# Remaining API call per min: 60
# 449 has completed all pagination
# Requesting page 0 for 588
# Saving 449 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/449-0.json
# Saving 449 completed
# Remaining API call per min: 59
# 588 has completed all pagination
# Requesting page 0 for 591
# Saving 588 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/588-0.json
# Saving 588 completed
# Remaining API call per min: 58
# 591 has completed all pagination
# Requesting page 0 for 602
# Saving 591 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/591-0.json
# Saving 591 completed
# Remaining API call per min: 57
# 602 has completed all pagination
# Requesting page 0 for 609
# Saving 602 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/602-0.json
# Saving 602 completed
# Remaining API call per min: 56
# 609 has completed all pagination
# Requesting page 0 for 610
# Saving 609 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/609-0.json
# Saving 609 completed
# Remaining API call per min: 55
# Requesting page 1 for 610
# Saving 610 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/610-0.json
# Saving 610 completed
# Remaining API call per min: 54
# Requesting page 2 for 610
# Saving 610 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/610-1.json
# Saving 610 completed
# Remaining API call per min: 53
# 610 has completed all pagination
# Requesting page 0 for 626
# Saving 610 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/610-2.json
# Saving 610 completed
# Remaining API call per min: 52
# 626 has completed all pagination
# Requesting page 0 for 1026
# Saving 626 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/626-0.json
# Saving 626 completed
# Remaining API call per min: 51
# 1026 has completed all pagination
# Requesting page 0 for 1027
# Saving 1026 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1026-0.json
# Saving 1026 completed
# Remaining API call per min: 50
# 1027 has completed all pagination
# Requesting page 0 for 1030
# Saving 1027 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1027-0.json
# Saving 1027 completed
# Remaining API call per min: 49
# 1030 has completed all pagination
# Requesting page 0 for 7
# Saving 1030 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1030-0.json
# Saving 1030 completed
# Remaining API call per min: 48
# 7 has completed all pagination
# Requesting page 0 for 780
# Saving 7 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/7-0.json
# Saving 7 completed
# Remaining API call per min: 47
# 780 has completed all pagination
# Requesting page 0 for 783
# Saving 780 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/780-0.json
# Saving 780 completed
# Remaining API call per min: 46
# 783 has completed all pagination
# Requesting page 0 for 798
# Saving 783 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/783-0.json
# Saving 783 completed
# Remaining API call per min: 45
# 798 has completed all pagination
# Requesting page 0 for 816
# Saving 798 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/798-0.json
# Saving 798 completed
# Remaining API call per min: 44
# 816 has completed all pagination
# Requesting page 0 for 828
# Saving 816 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/816-0.json
# Saving 816 completed
# Remaining API call per min: 43
# 828 has completed all pagination
# Requesting page 0 for 1087
# Saving 828 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/828-0.json
# Saving 828 completed
# Remaining API call per min: 42
# 1087 has completed all pagination
# Requesting page 0 for 1099
# Saving 1087 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1087-0.json
# Saving 1087 completed
# Remaining API call per min: 41
# 1099 has completed all pagination
# Requesting page 0 for 1102
# Saving 1099 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1099-0.json
# Saving 1099 completed
# Remaining API call per min: 40
# 1102 has completed all pagination
# Requesting page 0 for 1112
# Saving 1102 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1102-0.json
# Saving 1102 completed
# Remaining API call per min: 39
# 1112 has completed all pagination
# Requesting page 0 for 1116
# Saving 1112 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1112-0.json
# Saving 1112 completed
# Remaining API call per min: 38
# 1116 has completed all pagination
# Requesting page 0 for 1117
# Saving 1116 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1116-0.json
# Saving 1116 completed
# Remaining API call per min: 37
# 1117 has completed all pagination
# Requesting page 0 for 1120
# Saving 1117 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1117-0.json
# Saving 1117 completed
# Remaining API call per min: 36
# 1120 has completed all pagination
# Requesting page 0 for 1129
# Saving 1120 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1120-0.json
# Saving 1120 completed
# Remaining API call per min: 35
# 1129 has completed all pagination
# Requesting page 0 for 1135
# Saving 1129 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1129-0.json
# Saving 1129 completed
# Remaining API call per min: 34
# 1135 has completed all pagination
# Requesting page 0 for 641
# Saving 1135 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1135-0.json
# Saving 1135 completed
# Remaining API call per min: 33
# 641 has completed all pagination
# Requesting page 0 for 660
# Saving 641 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/641-0.json
# Saving 641 completed
# Remaining API call per min: 32
# 660 has completed all pagination
# Requesting page 0 for 683
# Saving 660 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/660-0.json
# Saving 660 completed
# Remaining API call per min: 31
# 683 has completed all pagination
# Requesting page 0 for 693
# Saving 683 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/683-0.json
# Saving 683 completed
# Remaining API call per min: 30
# 693 has completed all pagination
# Requesting page 0 for 719
# Saving 693 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/693-0.json
# Saving 693 completed
# Remaining API call per min: 29
# 719 has completed all pagination
# Requesting page 0 for 749
# Saving 719 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/719-0.json
# Saving 719 completed
# Remaining API call per min: 28
# 749 has completed all pagination
# Producer: Done
# Saving 749 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/749-0.json
# Saving 749 completed
# Batch: 550
# Consumer: Started
# Producer: Started
# Requesting page 0 for 758
# Remaining API call per min: 27
# 758 has completed all pagination
# Requesting page 0 for 1142
# Saving 758 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/758-0.json
# Saving 758 completed
# Remaining API call per min: 26
# 1142 has completed all pagination
# Requesting page 0 for 1143
# Saving 1142 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1142-0.json
# Saving 1142 completed
# Remaining API call per min: 25
# 1143 has completed all pagination
# Requesting page 0 for 1149
# Saving 1143 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1143-0.json
# Saving 1143 completed
# Remaining API call per min: 24
# 1149 has completed all pagination
# Requesting page 0 for 1161
# Saving 1149 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1149-0.json
# Saving 1149 completed
# Remaining API call per min: 23
# 1161 has completed all pagination
# Requesting page 0 for 1179
# Saving 1161 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1161-0.json
# Saving 1161 completed
# Remaining API call per min: 22
# 1179 has completed all pagination
# Requesting page 0 for 1181
# Saving 1179 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1179-0.json
# Saving 1179 completed
# Remaining API call per min: 21
# 1181 has completed all pagination
# Requesting page 0 for 1185
# Saving 1181 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1181-0.json
# Saving 1181 completed
# Remaining API call per min: 20
# 1185 has completed all pagination
# Requesting page 0 for 971
# Saving 1185 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1185-0.json
# Saving 1185 completed
# Remaining API call per min: 19
# 971 has completed all pagination
# Requesting page 0 for 980
# Saving 971 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/971-0.json
# Saving 971 completed
# Remaining API call per min: 18
# 980 has completed all pagination
# Requesting page 0 for 981
# Saving 980 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/980-0.json
# Saving 980 completed
# Remaining API call per min: 17
# 981 has completed all pagination
# Requesting page 0 for 985
# Saving 981 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/981-0.json
# Saving 981 completed
# Remaining API call per min: 16
# 985 has completed all pagination
# Requesting page 0 for 988
# Saving 985 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/985-0.json
# Saving 985 completed
# Remaining API call per min: 15
# 988 has completed all pagination
# Requesting page 0 for 989
# Saving 988 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/988-0.json
# Saving 988 completed
# Remaining API call per min: 14
# 989 has completed all pagination
# Requesting page 0 for 993
# Saving 989 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/989-0.json
# Saving 989 completed
# Remaining API call per min: 13
# 993 has completed all pagination
# Requesting page 0 for 997
# Saving 993 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/993-0.json
# Saving 993 completed
# Remaining API call per min: 12
# 997 has completed all pagination
# Requesting page 0 for 998
# Saving 997 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/997-0.json
# Saving 997 completed
# Remaining API call per min: 11
# 998 has completed all pagination
# Requesting page 0 for 999
# Saving 998 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/998-0.json
# Saving 998 completed
# Remaining API call per min: 10
# 999 has completed all pagination
# Requesting page 0 for 1001
# Saving 999 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/999-0.json
# Saving 999 completed
# Remaining API call per min: 9
# 1001 has completed all pagination
# Pause  to recover limit
# Saving 1001 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1001-0.json
# Saving 1001 completed
# Requesting page 0 for 1005
# Remaining API call per min: 8
# 1005 has completed all pagination
# Pause  to recover limit
# Saving 1005 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1005-0.json
# Saving 1005 completed
# Requesting page 0 for 1010
# Remaining API call per min: 89
# 1010 has completed all pagination
# Requesting page 0 for 1011
# Saving 1010 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1010-0.json
# Saving 1010 completed
# Remaining API call per min: 88
# 1011 has completed all pagination
# Requesting page 0 for 1017
# Saving 1011 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1011-0.json
# Saving 1011 completed
# Remaining API call per min: 87
# 1017 has completed all pagination
# Requesting page 0 for 1018
# Saving 1017 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1017-0.json
# Saving 1017 completed
# Remaining API call per min: 86
# 1018 has completed all pagination
# Requesting page 0 for 462
# Saving 1018 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1018-0.json
# Saving 1018 completed
# Remaining API call per min: 85
# 462 has completed all pagination
# Requesting page 0 for 465
# Saving 462 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/462-0.json
# Saving 462 completed
# Task was destroyed but it is pending!
# task: <Task pending name='Task-1310' coro=<consumer() running at C:\Users\JH\AppData\Local\Temp\ipykernel_22648\2744101087.py:9> wait_for=<Future pending cb=[Task.task_wakeup()]>>
# Remaining API call per min: 84
# 465 has completed all pagination
# Requesting page 0 for 472
# Saving 465 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/465-0.json
# Saving 465 completed
# Remaining API call per min: 83
# 472 has completed all pagination
# Requesting page 0 for 490
# Saving 472 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/472-0.json
# Saving 472 completed
# Remaining API call per min: 82
# Requesting page 1 for 490
# Saving 490 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/490-0.json
# Saving 490 completed
# Remaining API call per min: 81
# Requesting page 2 for 490
# Saving 490 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/490-1.json
# Saving 490 completed
# Remaining API call per min: 80
# 490 has completed all pagination
# Requesting page 0 for 492
# Saving 490 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/490-2.json
# Saving 490 completed
# Remaining API call per min: 79
# 492 has completed all pagination
# Requesting page 0 for 501
# Saving 492 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/492-0.json
# Saving 492 completed
# Remaining API call per min: 78
# 501 has completed all pagination
# Requesting page 0 for 517
# Saving 501 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/501-0.json
# Saving 501 completed
# Remaining API call per min: 77
# Requesting page 1 for 517
# Saving 517 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/517-0.json
# Saving 517 completed
# Remaining API call per min: 76
# Requesting page 2 for 517
# Saving 517 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/517-1.json
# Saving 517 completed
# Remaining API call per min: 75
# 517 has completed all pagination
# Requesting page 0 for 914
# Saving 517 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/517-2.json
# Saving 517 completed
# Remaining API call per min: 74
# 914 has completed all pagination
# Requesting page 0 for 924
# Saving 914 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/914-0.json
# Saving 914 completed
# Remaining API call per min: 73
# 924 has completed all pagination
# Requesting page 0 for 941
# Saving 924 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/924-0.json
# Saving 924 completed
# Remaining API call per min: 72
# 941 has completed all pagination
# Requesting page 0 for 942
# Saving 941 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/941-0.json
# Saving 941 completed
# Remaining API call per min: 71
# 942 has completed all pagination
# Requesting page 0 for 961
# Saving 942 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/942-0.json
# Saving 942 completed
# Remaining API call per min: 70
# 961 has completed all pagination
# Requesting page 0 for 1190
# Saving 961 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/961-0.json
# Saving 961 completed
# Remaining API call per min: 69
# 1190 has completed all pagination
# Requesting page 0 for 1208
# Saving 1190 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1190-0.json
# Saving 1190 completed
# Remaining API call per min: 68
# 1208 has completed all pagination
# Requesting page 0 for 1228
# Saving 1208 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1208-0.json
# Saving 1208 completed
# Remaining API call per min: 67
# 1228 has completed all pagination
# Requesting page 0 for 529
# Saving 1228 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1228-0.json
# Saving 1228 completed
# Remaining API call per min: 66
# 529 has completed all pagination
# Requesting page 0 for 553
# Saving 529 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/529-0.json
# Saving 529 completed
# Remaining API call per min: 65
# 553 has completed all pagination
# Requesting page 0 for 562
# Saving 553 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/553-0.json
# Saving 553 completed
# Remaining API call per min: 64
# 562 has completed all pagination
# Requesting page 0 for 863
# Saving 562 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/562-0.json
# Saving 562 completed
# Remaining API call per min: 63
# 863 has completed all pagination
# Requesting page 0 for 865
# Saving 863 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/863-0.json
# Saving 863 completed
# Remaining API call per min: 62
# 865 has completed all pagination
# Requesting page 0 for 875
# Saving 865 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/865-0.json
# Saving 865 completed
# Remaining API call per min: 61
# 875 has completed all pagination
# Requesting page 0 for 880
# Saving 875 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/875-0.json
# Saving 875 completed
# Remaining API call per min: 60
# 880 has completed all pagination
# Requesting page 0 for 882
# Saving 880 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/880-0.json
# Saving 880 completed
# Remaining API call per min: 59
# 882 has completed all pagination
# Requesting page 0 for 884
# Saving 882 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/882-0.json
# Saving 882 completed
# Remaining API call per min: 58
# 884 has completed all pagination
# Requesting page 0 for 886
# Saving 884 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/884-0.json
# Saving 884 completed
# Remaining API call per min: 57
# 886 has completed all pagination
# Requesting page 0 for 891
# Saving 886 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/886-0.json
# Saving 886 completed
# Remaining API call per min: 56
# 891 has completed all pagination
# Producer: Done
# Saving 891 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/891-0.json
# Saving 891 completed
# Batch: 600
# Consumer: Started
# Producer: Started
# Requesting page 0 for 895
# Remaining API call per min: 55
# 895 has completed all pagination
# Requesting page 0 for 900
# Saving 895 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/895-0.json
# Saving 895 completed
# Remaining API call per min: 54
# 900 has completed all pagination
# Requesting page 0 for 22
# Saving 900 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/900-0.json
# Saving 900 completed
# Remaining API call per min: 53
# Requesting page 1 for 22
# Saving 22 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/22-0.json
# Saving 22 completed
# Remaining API call per min: 52
# Requesting page 2 for 22
# Saving 22 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/22-1.json
# Saving 22 completed
# Remaining API call per min: 51
# Requesting page 3 for 22
# Saving 22 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/22-2.json
# Saving 22 completed
# Remaining API call per min: 50
# Requesting page 4 for 22
# Saving 22 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/22-3.json
# Saving 22 completed
# Remaining API call per min: 49
# 22 has completed all pagination
# Requesting page 0 for 336
# Saving 22 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/22-4.json
# Saving 22 completed
# Remaining API call per min: 48
# 336 has completed all pagination
# Requesting page 0 for 342
# Saving 336 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/336-0.json
# Saving 336 completed
# Remaining API call per min: 47
# 342 has completed all pagination
# Requesting page 0 for 346
# Saving 342 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/342-0.json
# Saving 342 completed
# Remaining API call per min: 46
# 346 has completed all pagination
# Requesting page 0 for 347
# Saving 346 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/346-0.json
# Saving 346 completed
# Remaining API call per min: 45
# 347 has completed all pagination
# Requesting page 0 for 368
# Saving 347 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/347-0.json
# Saving 347 completed
# Remaining API call per min: 44
# 368 has completed all pagination
# Requesting page 0 for 371
# Saving 368 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/368-0.json
# Saving 368 completed
# Remaining API call per min: 43
# 371 has completed all pagination
# Requesting page 0 for 378
# Saving 371 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/371-0.json
# Saving 371 completed
# Remaining API call per min: 42
# 378 has completed all pagination
# Requesting page 0 for 381
# Saving 378 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/378-0.json
# Saving 378 completed
# Remaining API call per min: 41
# 381 has completed all pagination
# Requesting page 0 for 384
# Saving 381 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/381-0.json
# Saving 381 completed
# Remaining API call per min: 40
# Requesting page 1 for 384
# Saving 384 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/384-0.json
# Saving 384 completed
# Remaining API call per min: 39
# Requesting page 2 for 384
# Saving 384 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/384-1.json
# Saving 384 completed
# Remaining API call per min: 38
# 384 has completed all pagination
# Requesting page 0 for 386
# Saving 384 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/384-2.json
# Saving 384 completed
# Remaining API call per min: 37
# 386 has completed all pagination
# Requesting page 0 for 387
# Saving 386 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/386-0.json
# Saving 386 completed
# Remaining API call per min: 36
# 387 has completed all pagination
# Requesting page 0 for 390
# Saving 387 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/387-0.json
# Saving 387 completed
# Remaining API call per min: 35
# 390 has completed all pagination
# Requesting page 0 for 393
# Saving 390 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/390-0.json
# Saving 390 completed
# Remaining API call per min: 34
# 393 has completed all pagination
# Requesting page 0 for 401
# Saving 393 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/393-0.json
# Saving 393 completed
# Remaining API call per min: 33
# 401 has completed all pagination
# Requesting page 0 for 412
# Saving 401 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/401-0.json
# Saving 401 completed
# Remaining API call per min: 32
# 412 has completed all pagination
# Requesting page 0 for 427
# Saving 412 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/412-0.json
# Saving 412 completed
# Remaining API call per min: 31
# Requesting page 1 for 427
# Saving 427 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/427-0.json
# Saving 427 completed
# Remaining API call per min: 30
# Requesting page 2 for 427
# Saving 427 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/427-1.json
# Saving 427 completed
# Remaining API call per min: 29
# Requesting page 3 for 427
# Saving 427 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/427-2.json
# Saving 427 completed
# Remaining API call per min: 28
# 427 has completed all pagination
# Requesting page 0 for 429
# Saving 427 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/427-3.json
# Saving 427 completed
# Remaining API call per min: 27
# 429 has completed all pagination
# Requesting page 0 for 439
# Saving 429 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/429-0.json
# Saving 429 completed
# Remaining API call per min: 26
# 439 has completed all pagination
# Requesting page 0 for 452
# Saving 439 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/439-0.json
# Saving 439 completed
# Remaining API call per min: 25
# 452 has completed all pagination
# Requesting page 0 for 580
# Saving 452 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/452-0.json
# Saving 452 completed
# Remaining API call per min: 24
# 580 has completed all pagination
# Requesting page 0 for 590
# Saving 580 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/580-0.json
# Saving 580 completed
# Remaining API call per min: 23
# 590 has completed all pagination
# Requesting page 0 for 595
# Saving 590 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/590-0.json
# Saving 590 completed
# Remaining API call per min: 22
# 595 has completed all pagination
# Requesting page 0 for 612
# Saving 595 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/595-0.json
# Saving 595 completed
# Remaining API call per min: 21
# 612 has completed all pagination
# Requesting page 0 for 630
# Saving 612 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/612-0.json
# Saving 612 completed
# Remaining API call per min: 20
# 630 has completed all pagination
# Requesting page 0 for 635
# Saving 630 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/630-0.json
# Saving 630 completed
# Remaining API call per min: 19
# 635 has completed all pagination
# Requesting page 0 for 637
# Saving 635 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/635-0.json
# Saving 635 completed
# Remaining API call per min: 18
# 637 has completed all pagination
# Requesting page 0 for 1025
# Saving 637 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/637-0.json
# Saving 637 completed
# Remaining API call per min: 17
# 1025 has completed all pagination
# Requesting page 0 for 1029
# Saving 1025 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1025-0.json
# Saving 1025 completed
# Remaining API call per min: 16
# 1029 has completed all pagination
# Requesting page 0 for 1048
# Saving 1029 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1029-0.json
# Saving 1029 completed
# Remaining API call per min: 15
# 1048 has completed all pagination
# Requesting page 0 for 1049
# Saving 1048 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1048-0.json
# Saving 1048 completed
# Remaining API call per min: 14
# 1049 has completed all pagination
# Requesting page 0 for 1079
# Saving 1049 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1049-0.json
# Saving 1049 completed
# Remaining API call per min: 13
# 1079 has completed all pagination
# Requesting page 0 for 796
# Saving 1079 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1079-0.json
# Saving 1079 completed
# Remaining API call per min: 12
# 796 has completed all pagination
# Requesting page 0 for 797
# Saving 796 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/796-0.json
# Saving 796 completed
# Remaining API call per min: 11
# 797 has completed all pagination
# Requesting page 0 for 810
# Saving 797 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/797-0.json
# Saving 797 completed
# Remaining API call per min: 10
# 810 has completed all pagination
# Requesting page 0 for 814
# Saving 810 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/810-0.json
# Saving 810 completed
# Remaining API call per min: 9
# Pause  to recover limit
# Saving 814 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/814-0.json
# Saving 814 completed
# Requesting page 1 for 814
# Remaining API call per min: 8
# Pause  to recover limit
# Saving 814 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/814-1.json
# Saving 814 completed
# Requesting page 2 for 814
# Remaining API call per min: 89
# 814 has completed all pagination
# Requesting page 0 for 821
# Saving 814 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/814-2.json
# Saving 814 completed
# Remaining API call per min: 88
# 821 has completed all pagination
# Requesting page 0 for 834
# Saving 821 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/821-0.json
# Saving 821 completed
# Remaining API call per min: 87
# Requesting page 1 for 834
# Saving 834 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/834-0.json
# Saving 834 completed
# Remaining API call per min: 86
# Requesting page 2 for 834
# Saving 834 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/834-1.json
# Saving 834 completed
# Remaining API call per min: 85
# 834 has completed all pagination
# Requesting page 0 for 836
# Saving 834 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/834-2.json
# Saving 834 completed
# Remaining API call per min: 84
# 836 has completed all pagination
# Requesting page 0 for 837
# Saving 836 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/836-0.json
# Saving 836 completed
# Remaining API call per min: 83
# 837 has completed all pagination
# Requesting page 0 for 839
# Saving 837 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/837-0.json
# Saving 837 completed
# Remaining API call per min: 82
# 839 has completed all pagination
# Requesting page 0 for 840
# Saving 839 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/839-0.json
# Saving 839 completed
# Remaining API call per min: 81
# 840 has completed all pagination
# Requesting page 0 for 1085
# Saving 840 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/840-0.json
# Saving 840 completed
# Remaining API call per min: 80
# 1085 has completed all pagination
# Requesting page 0 for 1088
# Saving 1085 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1085-0.json
# Saving 1085 completed
# Remaining API call per min: 79
# 1088 has completed all pagination
# Requesting page 0 for 1089
# Saving 1088 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1088-0.json
# Saving 1088 completed
# Remaining API call per min: 78
# 1089 has completed all pagination
# Requesting page 0 for 1103
# Saving 1089 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1089-0.json
# Saving 1089 completed
# Remaining API call per min: 77
# 1103 has completed all pagination
# Requesting page 0 for 1110
# Saving 1103 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1103-0.json
# Saving 1103 completed
# Remaining API call per min: 76
# Requesting page 1 for 1110
# Saving 1110 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1110-0.json
# Saving 1110 completed
# Remaining API call per min: 75
# Requesting page 2 for 1110
# Saving 1110 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1110-1.json
# Saving 1110 completed
# Remaining API call per min: 74
# 1110 has completed all pagination
# Requesting page 0 for 1113
# Saving 1110 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1110-2.json
# Saving 1110 completed
# Remaining API call per min: 73
# 1113 has completed all pagination
# Producer: Done
# Saving 1113 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1113-0.json
# Saving 1113 completed
# Batch: 650
# Consumer: Started
# Producer: Started
# Requesting page 0 for 1115
# Remaining API call per min: 72
# 1115 has completed all pagination
# Requesting page 0 for 1126
# Saving 1115 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1115-0.json
# Saving 1115 completed
# Remaining API call per min: 71
# 1126 has completed all pagination
# Requesting page 0 for 642
# Saving 1126 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1126-0.json
# Saving 1126 completed
# Remaining API call per min: 70
# 642 has completed all pagination
# Requesting page 0 for 667
# Saving 642 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/642-0.json
# Saving 642 completed
# Remaining API call per min: 69
# 667 has completed all pagination
# Requesting page 0 for 671
# Saving 667 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/667-0.json
# Saving 667 completed
# Remaining API call per min: 68
# 671 has completed all pagination
# Requesting page 0 for 677
# Saving 671 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/671-0.json
# Saving 671 completed
# Remaining API call per min: 67
# 677 has completed all pagination
# Requesting page 0 for 678
# Saving 677 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/677-0.json
# Saving 677 completed
# Remaining API call per min: 66
# 678 has completed all pagination
# Requesting page 0 for 684
# Saving 678 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/678-0.json
# Saving 678 completed
# Remaining API call per min: 65
# 684 has completed all pagination
# Requesting page 0 for 694
# Saving 684 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/684-0.json
# Saving 684 completed
# Remaining API call per min: 64
# 694 has completed all pagination
# Requesting page 0 for 705
# Saving 694 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/694-0.json
# Saving 694 completed
# Remaining API call per min: 63
# 705 has completed all pagination
# Requesting page 0 for 722
# Saving 705 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/705-0.json
# Saving 705 completed
# Remaining API call per min: 62
# 722 has completed all pagination
# Requesting page 0 for 729
# Saving 722 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/722-0.json
# Saving 722 completed
# Remaining API call per min: 61
# 729 has completed all pagination
# Requesting page 0 for 743
# Saving 729 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/729-0.json
# Saving 729 completed
# Remaining API call per min: 60
# 743 has completed all pagination
# Requesting page 0 for 744
# Saving 743 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/743-0.json
# Saving 743 completed
# Remaining API call per min: 59
# 744 has completed all pagination
# Requesting page 0 for 755
# ...
# Remaining API call per min: 9
# 519 has completed all pagination
# Pause  to recover limit
# Saving 519 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/519-0.json
# Saving 519 completed
# Requesting page 0 for 526
# Remaining API call per min: 8
# 526 has completed all pagination
# Pause  to recover limit
# Saving 526 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/526-0.json
# Saving 526 completed
# Requesting page 0 for 541
# Remaining API call per min: 89
# 541 has completed all pagination
# Requesting page 0 for 552
# Saving 541 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/541-0.json
# Saving 541 completed
# Remaining API call per min: 88
# Requesting page 1 for 552
# Saving 552 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/552-0.json
# Saving 552 completed
# Remaining API call per min: 87
# Requesting page 2 for 552
# Saving 552 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/552-1.json
# Saving 552 completed
# Remaining API call per min: 86
# Requesting page 3 for 552
# Saving 552 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/552-2.json
# Saving 552 completed
# Remaining API call per min: 85
# 552 has completed all pagination
# Requesting page 0 for 564
# Saving 552 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/552-3.json
# Saving 552 completed
# Remaining API call per min: 84
# 564 has completed all pagination
# Requesting page 0 for 568
# Saving 564 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/564-0.json
# Saving 564 completed
# Remaining API call per min: 83
# 568 has completed all pagination
# Requesting page 0 for 571
# Saving 568 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/568-0.json
# Saving 568 completed
# Remaining API call per min: 82
# 571 has completed all pagination
# Requesting page 0 for 850
# Saving 571 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/571-0.json
# Saving 571 completed
# Remaining API call per min: 81
# 850 has completed all pagination
# Requesting page 0 for 861
# Saving 850 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/850-0.json
# Saving 850 completed
# Remaining API call per min: 80
# 861 has completed all pagination
# Requesting page 0 for 866
# Saving 861 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/861-0.json
# Saving 861 completed
# Remaining API call per min: 79
# 866 has completed all pagination
# Requesting page 0 for 872
# Saving 866 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/866-0.json
# Saving 866 completed
# Remaining API call per min: 78
# 872 has completed all pagination
# Requesting page 0 for 878
# Saving 872 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/872-0.json
# Saving 872 completed
# Remaining API call per min: 77
# Requesting page 1 for 878
# Saving 878 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/878-0.json
# Saving 878 completed
# Remaining API call per min: 76
# Requesting page 2 for 878
# Saving 878 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/878-1.json
# Saving 878 completed
# Remaining API call per min: 75
# 878 has completed all pagination
# Requesting page 0 for 899
# Saving 878 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/878-2.json
# Saving 878 completed
# Remaining API call per min: 74
# 899 has completed all pagination
# Requesting page 0 for 17
# Saving 899 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/899-0.json
# Saving 899 completed
# Remaining API call per min: 73
# 17 has completed all pagination
# Requesting page 0 for 343
# Saving 17 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/17-0.json
# Saving 17 completed
# Remaining API call per min: 72
# 343 has completed all pagination
# Requesting page 0 for 349
# Saving 343 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/343-0.json
# Saving 343 completed
# Remaining API call per min: 71
# 349 has completed all pagination
# Requesting page 0 for 359
# Saving 349 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/349-0.json
# Saving 349 completed
# Remaining API call per min: 70
# 359 has completed all pagination
# Requesting page 0 for 360
# Saving 359 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/359-0.json
# Saving 359 completed
# Remaining API call per min: 69
# 360 has completed all pagination
# Requesting page 0 for 362
# Saving 360 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/360-0.json
# Saving 360 completed
# Remaining API call per min: 68
# 362 has completed all pagination
# Requesting page 0 for 366
# Saving 362 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/362-0.json
# Saving 362 completed
# Remaining API call per min: 67
# 366 has completed all pagination
# Requesting page 0 for 367
# Saving 366 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/366-0.json
# Saving 366 completed
# Remaining API call per min: 66
# 367 has completed all pagination
# Requesting page 0 for 375
# Saving 367 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/367-0.json
# Saving 367 completed
# Remaining API call per min: 65
# 375 has completed all pagination
# Requesting page 0 for 383
# Saving 375 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/375-0.json
# Saving 375 completed
# Remaining API call per min: 64
# 383 has completed all pagination
# Requesting page 0 for 406
# Saving 383 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/383-0.json
# Saving 383 completed
# Remaining API call per min: 63
# 406 has completed all pagination
# Requesting page 0 for 418
# Saving 406 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/406-0.json
# Saving 406 completed
# Remaining API call per min: 62
# 418 has completed all pagination
# Requesting page 0 for 423
# Saving 418 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/418-0.json
# Saving 418 completed
# Remaining API call per min: 61
# 423 has completed all pagination
# Requesting page 0 for 451
# Saving 423 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/423-0.json
# Saving 423 completed
# Remaining API call per min: 60
# 451 has completed all pagination
# Requesting page 0 for 577
# Saving 451 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/451-0.json
# Saving 451 completed
# Remaining API call per min: 59
# 577 has completed all pagination
# Requesting page 0 for 581
# Saving 577 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/577-0.json
# Saving 577 completed
# Remaining API call per min: 58
# 581 has completed all pagination
# Requesting page 0 for 596
# Saving 581 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/581-0.json
# Saving 581 completed
# Remaining API call per min: 57
# 596 has completed all pagination
# Requesting page 0 for 600
# Saving 596 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/596-0.json
# Saving 596 completed
# Remaining API call per min: 56
# 600 has completed all pagination
# Requesting page 0 for 619
# Saving 600 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/600-0.json
# Saving 600 completed
# Remaining API call per min: 55
# 619 has completed all pagination
# Requesting page 0 for 629
# Saving 619 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/619-0.json
# Saving 619 completed
# Remaining API call per min: 54
# 629 has completed all pagination
# Requesting page 0 for 636
# Saving 629 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/629-0.json
# Saving 629 completed
# Remaining API call per min: 53
# 636 has completed all pagination
# Requesting page 0 for 1031
# Saving 636 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/636-0.json
# Saving 636 completed
# Remaining API call per min: 52
# 1031 has completed all pagination
# Requesting page 0 for 1038
# Saving 1031 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1031-0.json
# Saving 1031 completed
# Remaining API call per min: 51
# 1038 has completed all pagination
# Requesting page 0 for 1051
# Saving 1038 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1038-0.json
# Saving 1038 completed
# Remaining API call per min: 50
# 1051 has completed all pagination
# Requesting page 0 for 1053
# Saving 1051 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1051-0.json
# Saving 1051 completed
# Remaining API call per min: 49
# 1053 has completed all pagination
# Requesting page 0 for 1066
# Saving 1053 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1053-0.json
# Saving 1053 completed
# Remaining API call per min: 48
# 1066 has completed all pagination
# Requesting page 0 for 1072
# Saving 1066 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1066-0.json
# Saving 1066 completed
# Remaining API call per min: 47
# 1072 has completed all pagination
# Requesting page 0 for 8
# Saving 1072 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1072-0.json
# Saving 1072 completed
# Remaining API call per min: 46
# 8 has completed all pagination
# Requesting page 0 for 789
# Saving 8 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/8-0.json
# Saving 8 completed
# Remaining API call per min: 45
# 789 has completed all pagination
# Requesting page 0 for 819
# Saving 789 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/789-0.json
# Saving 789 completed
# Remaining API call per min: 44
# 819 has completed all pagination
# Requesting page 0 for 825
# Saving 819 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/819-0.json
# Saving 819 completed
# Remaining API call per min: 43
# 825 has completed all pagination
# Requesting page 0 for 827
# Saving 825 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/825-0.json
# Saving 825 completed
# Remaining API call per min: 42
# 827 has completed all pagination
# Requesting page 0 for 830
# Saving 827 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/827-0.json
# Saving 827 completed
# Remaining API call per min: 41
# 830 has completed all pagination
# Requesting page 0 for 838
# Saving 830 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/830-0.json
# Saving 830 completed
# Remaining API call per min: 40
# 838 has completed all pagination
# Producer: Done
# Saving 838 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/838-0.json
# Saving 838 completed
# Batch: 750
# Consumer: Started
# Producer: Started
# Requesting page 0 for 1082
# Remaining API call per min: 39
# 1082 has completed all pagination
# Requesting page 0 for 1084
# Saving 1082 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1082-0.json
# Saving 1082 completed
# Remaining API call per min: 38
# 1084 has completed all pagination
# Requesting page 0 for 1090
# Saving 1084 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1084-0.json
# Saving 1084 completed
# Remaining API call per min: 37
# Requesting page 1 for 1090
# Saving 1090 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1090-0.json
# Saving 1090 completed
# Remaining API call per min: 36
# Requesting page 2 for 1090
# Saving 1090 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1090-1.json
# Saving 1090 completed
# Remaining API call per min: 35
# 1090 has completed all pagination
# Requesting page 0 for 1092
# Saving 1090 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1090-2.json
# Saving 1090 completed
# Remaining API call per min: 34
# 1092 has completed all pagination
# Requesting page 0 for 1106
# Saving 1092 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1092-0.json
# Saving 1092 completed
# Remaining API call per min: 33
# 1106 has completed all pagination
# Requesting page 0 for 1118
# Saving 1106 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1106-0.json
# Saving 1106 completed
# Remaining API call per min: 32
# 1118 has completed all pagination
# Requesting page 0 for 1123
# Saving 1118 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1118-0.json
# Saving 1118 completed
# Remaining API call per min: 31
# 1123 has completed all pagination
# Requesting page 0 for 1128
# Saving 1123 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1123-0.json
# Saving 1123 completed
# Remaining API call per min: 30
# 1128 has completed all pagination
# Requesting page 0 for 1132
# Saving 1128 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1128-0.json
# Saving 1128 completed
# Remaining API call per min: 29
# Requesting page 1 for 1132
# Saving 1132 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1132-0.json
# Saving 1132 completed
# Remaining API call per min: 28
# Requesting page 2 for 1132
# Saving 1132 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1132-1.json
# Saving 1132 completed
# Remaining API call per min: 27
# 1132 has completed all pagination
# Producer: Done
# Saving 1132 at c:/Users/JH/project/road-to-data-engineer/graph-search/graph-search-data-engineering/raw/entity/anime-character/1132-2.json
# Saving 1132 completed

# %%
filenames = [filename.name.split('-')[0] for filename in storage_path.glob('*.json')]

# %%
print(len(filenames))
print(len(set(filenames)))
# Out:
# 932
# 759
